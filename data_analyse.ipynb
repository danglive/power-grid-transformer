# %%
import os
import sys
import numpy as np
import torch
import logging
import json
from pathlib import Path

# Thêm thư mục gốc vào sys.path
sys.path.insert(0, os.path.abspath('.'))

# Cấu hình logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(name)s - %(levelname)s - %(message)s')
logger = logging.getLogger("test_data_module")

# Load config
with open('config.json', 'r') as f:
    config = json.load(f)

# Import module data
from src.data import (
    QTransformerDataModule, 
    load_npz_data, 
    analyze_dataset_statistics,
    create_data_visualizations
)

# Kiểm tra tồn tại của các file dữ liệu
train_val_file = Path(config['dataset_dir']) / config['training_files'][0]
test_file = Path(config['dataset_dir']) / config['testing_files'][0]

logger.info(f"Checking training file: {train_val_file} - exists: {train_val_file.exists()}")
logger.info(f"Checking test file: {test_file} - exists: {test_file.exists()}")

# Phân tích cấu trúc dữ liệu
logger.info("Analyzing training data structure...")
train_data = load_npz_data(str(train_val_file))
logger.info(f"Training data has {len(train_data['obs'])} samples")

# Tạo visualizations
viz_dir = "data_visualizations"
os.makedirs(viz_dir, exist_ok=True)
logger.info(f"Creating visualizations in {viz_dir}")
create_data_visualizations(train_data, viz_dir)

# Tạo DataModule
logger.info("Creating QTransformerDataModule...")
data_module = QTransformerDataModule(config)
data_module.setup()

# Kiểm tra DataLoaders
train_loader = data_module.get_train_dataloader()
val_loader = data_module.get_val_dataloader()
test_loader = data_module.get_test_dataloader()

logger.info(f"Train loader: {len(train_loader)} batches")
logger.info(f"Validation loader: {len(val_loader)} batches")
logger.info(f"Test loader: {len(test_loader)} batches" if test_loader else "No test loader")

# Lấy và kiểm tra một batch
logger.info("Getting a batch from train loader...")
batch = next(iter(train_loader))
logger.info(f"Batch keys: {list(batch.keys())}")
logger.info(f"Observations shape: {batch['observation'].shape}")
logger.info(f"Action vectors shape: {batch['action_vectors'].shape}")
logger.info(f"Rho values shape: {batch['rho_values'].shape}")
logger.info(f"Soft labels shape: {batch['soft_labels'].shape}")

logger.info("QTransformerDataModule test completed successfully!")
# Out:
# 2025-04-16 23:01:38,884 - src.data - INFO - Loaded Q-Transformer data module with 23 components
# 2025-04-16 23:01:38,885 - test_data_module - INFO - Checking training file: train_val.npz - exists: True
# 2025-04-16 23:01:38,886 - test_data_module - INFO - Checking test file: test.npz - exists: True
# 2025-04-16 23:01:38,887 - test_data_module - INFO - Analyzing training data structure...
# 2025-04-16 23:01:54,417 - src.data.utils - INFO - Loaded train_val.npz in 15.53 seconds
# 2025-04-16 23:01:54,419 - src.data.utils - INFO - Found keys: ['obs', 'best_action', 'timestep', 'act_rho', 'soft_labels', 'act_vect']
# 2025-04-16 23:01:54,420 - src.data.utils - INFO -   obs: (50376, 3819), float32
# 2025-04-16 23:01:54,421 - src.data.utils - INFO -   best_action: (50376,), <U72
# 2025-04-16 23:01:54,422 - src.data.utils - INFO -   timestep: (50376,), datetime64[us]
# 2025-04-16 23:01:54,423 - src.data.utils - INFO -   act_rho: (50376, 50), [('action', '<U73'), ('rho_max', '<f4')]
# 2025-04-16 23:01:54,424 - src.data.utils - INFO -   soft_labels: (50376, 50), object
# 2025-04-16 23:01:54,425 - src.data.utils - INFO -   act_vect: (50376, 50, 2), object
# 2025-04-16 23:01:54,426 - test_data_module - INFO - Training data has 50376 samples
# 2025-04-16 23:01:54,427 - test_data_module - INFO - Creating visualizations in data_visualizations
# 2025-04-16 23:01:54,428 - src.data.utils - INFO - Creating data visualizations in data_visualizations
# 2025-04-16 23:01:54,972 - src.data.utils - INFO - Created observation distribution visualizations
# 2025-04-16 23:01:55,509 - src.data.utils - INFO - Created rho distribution visualization
# 2025-04-16 23:01:56,113 - src.data.utils - INFO - Created soft label distribution visualization
# 2025-04-16 23:01:56,348 - src.data.utils - INFO - Created timestep distribution visualization
# 2025-04-16 23:01:56,351 - test_data_module - INFO - Creating QTransformerDataModule...
# 2025-04-16 23:01:56,352 - src.data.qtransformer_data - INFO - Loading training data from 1 files...
# 2025-04-16 23:01:56,353 - src.data.qtransformer_data - INFO - Loading file: train_val.npz
# 2025-04-16 23:02:11,150 - src.data.enhanced_splitter - INFO - Splitting 50376 samples with strategy: stratified_temporal
# 2025-04-16 23:02:16,156 - src.data.enhanced_splitter - INFO - === Split Summary ===
# 2025-04-16 23:02:16,158 - src.data.enhanced_splitter - INFO - Train samples: 42840
# 2025-04-16 23:02:16,159 - src.data.enhanced_splitter - INFO - Val samples:   7536
# 2025-04-16 23:02:16,160 - src.data.enhanced_splitter - INFO - Test samples:  0
# 2025-04-16 23:02:16,160 - src.data.enhanced_splitter - INFO - Train time: 2021-01-04T07:45:00.000000 → 2023-12-07T12:55:00.000000
# 2025-04-16 23:02:16,161 - src.data.enhanced_splitter - INFO - Val time:   2021-09-27T14:40:00.000000 → 2023-12-22T11:30:00.000000
# 2025-04-16 23:02:16,162 - src.data.enhanced_splitter - INFO - JSD Drift (train vs val label dist): 0.0000
# 2025-04-16 23:02:16,163 - src.data.enhanced_splitter - INFO - JSD Drift (train vs val action dist): 0.0097
# 2025-04-16 23:02:16,164 - src.data.enhanced_splitter - INFO - Rate of unseen labels in val:       0.00%
# 2025-04-16 23:02:16,164 - src.data.enhanced_splitter - INFO - Maximum weekly JSD: 0.6399 (week 2023-07-06)
# 2025-04-16 23:02:16,165 - src.data.enhanced_splitter - INFO - ⚠️  2.83% of val samples are from future relative to train
# 2025-04-16 23:02:16,166 - src.data.enhanced_splitter - INFO -    Future val time range: 2023-12-07T13:00:00.000000 → 2023-12-22T11:30:00.000000
# 2025-04-16 23:02:16,167 - src.data.enhanced_splitter - INFO - Note: No test data in this split (use external test file if needed)
# 2025-04-16 23:02:17,851 - matplotlib.category - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-04-16 23:02:17,855 - matplotlib.category - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-04-16 23:02:18,385 - matplotlib.category - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-04-16 23:02:18,394 - matplotlib.category - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-04-16 23:02:19,281 - src.data.enhanced_splitter - INFO - Saved split report to data_cache/visualizations/split_report.json
# 2025-04-16 23:02:19,283 - src.data.qtransformer_data - INFO - Creating training dataset...
# 2025-04-16 23:02:19,303 - src.data.qtransformer_data - INFO - Dataset dimensions - Observations: 3819, Actions: 50, Action vector: 1152
# 2025-04-16 23:02:19,304 - src.data.qtransformer_data - INFO - Prefetching data for faster access...
# 2025-04-16 23:02:19,606 - src.data.qtransformer_data - INFO - Data prefetching completed in 0.30 seconds
# 2025-04-16 23:02:19,607 - src.data.qtransformer_data - INFO - Action cache stats: {'size': 50, 'capacity': 10000, 'usage': 0.005, 'access_count': 50000}
# 2025-04-16 23:02:19,608 - src.data.qtransformer_data - INFO - Soft label cache stats: {'size': 50, 'capacity': 10000, 'usage': 0.005, 'access_count': 50000}
# 2025-04-16 23:02:19,609 - src.data.qtransformer_data - INFO - Creating validation dataset...
# 2025-04-16 23:02:19,611 - src.data.qtransformer_data - INFO - Dataset dimensions - Observations: 3819, Actions: 50, Action vector: 1152
# 2025-04-16 23:02:19,612 - src.data.qtransformer_data - INFO - Prefetching data for faster access...
# 2025-04-16 23:02:19,907 - src.data.qtransformer_data - INFO - Data prefetching completed in 0.29 seconds
# 2025-04-16 23:02:19,908 - src.data.qtransformer_data - INFO - Action cache stats: {'size': 50, 'capacity': 10000, 'usage': 0.005, 'access_count': 50000}
# 2025-04-16 23:02:19,909 - src.data.qtransformer_data - INFO - Soft label cache stats: {'size': 50, 'capacity': 10000, 'usage': 0.005, 'access_count': 50000}
# 2025-04-16 23:02:19,910 - src.data.qtransformer_data - INFO - Loading test data...
# 2025-04-16 23:02:19,911 - src.data.qtransformer_data - INFO - Loading testing data from 1 files...
# 2025-04-16 23:02:19,912 - src.data.qtransformer_data - INFO - Loading file: test.npz
# 2025-04-16 23:02:21,842 - src.data.qtransformer_data - INFO - External test dataset contains 6614 samples
# 2025-04-16 23:02:21,844 - src.data.qtransformer_data - INFO - Test time range: 2024-05-16T13:35:00.000000 → 2024-12-31T23:50:00.000000
# 2025-04-16 23:02:21,845 - src.data.qtransformer_data - INFO - Creating test dataset...
# 2025-04-16 23:02:21,847 - src.data.qtransformer_data - INFO - Dataset dimensions - Observations: 3819, Actions: 50, Action vector: 1152
# 2025-04-16 23:02:21,847 - src.data.qtransformer_data - INFO - Prefetching data for faster access...
# 2025-04-16 23:02:22,141 - src.data.qtransformer_data - INFO - Data prefetching completed in 0.29 seconds
# 2025-04-16 23:02:22,142 - src.data.qtransformer_data - INFO - Action cache stats: {'size': 50, 'capacity': 10000, 'usage': 0.005, 'access_count': 50000}
# 2025-04-16 23:02:22,143 - src.data.qtransformer_data - INFO - Soft label cache stats: {'size': 50, 'capacity': 10000, 'usage': 0.005, 'access_count': 50000}
# 2025-04-16 23:02:22,144 - src.data.qtransformer_data - INFO - Computing dataset statistics...
# 2025-04-16 23:02:22,145 - src.data.base - INFO - Computing dataset statistics...
# 2025-04-16 23:02:28,288 - src.data.base - INFO - Statistics computation completed in 6.14 seconds
# 2025-04-16 23:02:28,291 - src.data.base - INFO - Dataset Statistics:
# 2025-04-16 23:02:28,292 - src.data.base - INFO -   Number of samples: 50376
# 2025-04-16 23:02:28,293 - src.data.base - INFO -   Observation shape: torch.Size([3819])
# 2025-04-16 23:02:28,293 - src.data.base - INFO -   Action dimension: 1152
# 2025-04-16 23:02:28,294 - src.data.base - INFO -   Actions per sample: 50
# 2025-04-16 23:02:28,295 - src.data.base - INFO -   Feature range: [-531256.7500, 477015.7188]
# 2025-04-16 23:02:28,296 - src.data.base - INFO -   Feature mean range: [-531345.1250, 477052.5625]
# 2025-04-16 23:02:28,297 - src.data.base - INFO -   Rho range: [0.3417, 6.4651]
# 2025-04-16 23:02:28,298 - src.data.base - INFO -   Rho mean/std: 1.1497/0.2808
# 2025-04-16 23:02:28,301 - src.data.base - INFO - Statistics cached to data_cache/dataset_stats.pkl
# 2025-04-16 23:02:28,304 - test_data_module - INFO - Train loader: 335 batches
# 2025-04-16 23:02:28,306 - test_data_module - INFO - Validation loader: 59 batches
# 2025-04-16 23:02:28,306 - test_data_module - INFO - Test loader: 52 batches
# 2025-04-16 23:02:28,307 - test_data_module - INFO - Getting a batch from train loader...
# 2025-04-16 23:02:29,726 - test_data_module - INFO - Batch keys: ['observation', 'action_vectors', 'rho_values', 'soft_labels', 'timestep', 'idx', 'best_action']
# 2025-04-16 23:02:29,728 - test_data_module - INFO - Observations shape: torch.Size([128, 3819])
# 2025-04-16 23:02:29,730 - test_data_module - INFO - Action vectors shape: torch.Size([128, 50, 1152])
# 2025-04-16 23:02:29,731 - test_data_module - INFO - Rho values shape: torch.Size([128, 50])
# 2025-04-16 23:02:29,732 - test_data_module - INFO - Soft labels shape: torch.Size([128, 50])
# 2025-04-16 23:02:29,733 - test_data_module - INFO - QTransformerDataModule test completed successfully!
